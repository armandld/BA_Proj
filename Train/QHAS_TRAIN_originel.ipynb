# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# On se déplace dans le dossier que tu as uploadé
# %cd /content/drive/MyDrive/BA_Proj/
# !ls /content/drive/MyDrive/BA_Proj/
# On donne les droits d'exécution au script bash
# !chmod +x TrainHP_GoogleColab.sh
# Out:
# /content/drive/MyDrive/BA_Proj

# %%
# 1. On récupère les dernières infos du serveur sans fusionner
# !git fetch origin main

# 2. On force le dossier local à s'aligner sur l'origine
# !git reset --hard origin/main

# 3. (Optionnel) On supprime les fichiers non suivis par git qui trainent
# !git clean -fd
# Out:
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 31 (delta 6), reused 31 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (31/31), 5.49 MiB | 365.00 KiB/s, done.
# From https://github.com/armandld/BA_Proj
#  * branch            main       -> FETCH_HEAD
#    c55849f..0eb889d  main       -> origin/main
# Updating files: 100% (231/231), done.
# HEAD is now at 0eb889d updated fine tuning of the training
# Removing "advanced_project_idea/Ide\314\201e pour ame\314\201liorer projet.rtf"
# Removing logs/pipeline_training[2026-03-04_14-41-15].log
# Removing logs/pipeline_training[2026-03-05_10-02-59].log

# %%
# !bash TrainHP_GoogleColab.sh
# Out:
# ☁️ Environnement Google Colab détecté. Installation des dépendances via pip...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 57.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ✅ Dépendances installées avec succès sur Colab.
# [2026-03-05 19:56:19] ==============================================================
# [2026-03-05 19:56:19] 🚀 Starting Training Q-HAS' Hyper Parameters: Quantum-Hierarchical Adaptive Steering Pipeline - Variational Workflow
# [2026-03-05 19:56:19] Script Path: /content/drive/MyDrive/BA_Proj/src
# ...
